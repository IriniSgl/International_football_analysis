# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta

# %%
goalscorers = pd.read_csv("goalscorers.csv")
results = pd.read_csv("results.csv")
shootouts = pd.read_csv("shootouts.csv")

# %%
goalscorers.shape
# Out:
# (44110, 8)

# %%
results.shape
# Out:
# (47126, 9)

# %%
shootouts.shape
# Out:
# (636, 5)

# %%
goalscorers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44110 entries, 0 to 44109
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       44110 non-null  object
#  1   home_team  44110 non-null  object
#  2   away_team  44110 non-null  object
#  3   team       44110 non-null  object
#  4   scorer     44060 non-null  object
#  5   minute     43847 non-null  float64
#  6   own_goal   44108 non-null  object
#  7   penalty    44108 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 2.7+ MB

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47126 entries, 0 to 47125
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        47126 non-null  object
#  1   home_team   47111 non-null  object
#  2   away_team   47111 non-null  object
#  3   home_score  47075 non-null  float64
#  4   away_score  47075 non-null  float64
#  5   tournament  47126 non-null  object
#  6   city        47126 non-null  object
#  7   country     47126 non-null  object
#  8   neutral     47126 non-null  bool
# dtypes: bool(1), float64(2), object(6)
# memory usage: 2.9+ MB

# %%
shootouts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           636 non-null    object
#  1   home_team      636 non-null    object
#  2   away_team      636 non-null    object
#  3   winner         636 non-null    object
#  4   first_shooter  222 non-null    object
# dtypes: object(5)
# memory usage: 25.0+ KB

# %%
goalscorers.head()
# Out:
#          date  home_team away_team       team            scorer  minute  \
# 0  1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    44.0
# 1  1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    55.0
# 2  1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    70.0
# 3  1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    75.0
# 4  1916-07-06  Argentina     Chile  Argentina     Alberto Ohaco     2.0
#
#   own_goal penalty
# 0    False   False
# 1    False   False
# 2    False   False
# 3    False   False
# 4    False   False

# %%
results.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England         0.0         0.0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland         4.0         2.0   Friendly   London
# 2  1874-03-07  Scotland   England         2.0         1.0   Friendly  Glasgow
# 3  1875-03-06   England  Scotland         2.0         2.0   Friendly   London
# 4  1876-03-04  Scotland   England         3.0         0.0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
shootouts =  shootouts[(shootouts['date']>'2000-01-01') & (shootouts['date']<'2024-01-01')]

# %%
shootouts
# Out:
#           date        home_team      away_team         winner  first_shooter
# 262 2000-02-04          Romania        Georgia        Romania            NaN
# 263 2000-02-12     South Africa        Tunisia   South Africa   South Africa
# 264 2000-02-13          Nigeria       Cameroon       Cameroon        Nigeria
# 265 2000-02-19    United States       Colombia       Colombia  United States
# 266 2000-03-19         Suriname    Saint Lucia       Suriname            NaN
# ..         ...              ...            ...            ...            ...
# 617 2023-09-07             Iraq          India           Iraq          India
# 618 2023-09-10         Thailand           Iraq           Iraq       Thailand
# 619 2023-10-13             Iraq          Qatar          Qatar          Qatar
# 620 2023-11-21           Mexico       Honduras         Mexico         Mexico
# 621 2023-12-02  Solomon Islands  New Caledonia  New Caledonia            NaN
#
# [360 rows x 5 columns]

# %%
shootouts2 = pd.concat(shootouts['home_team'],shootouts['away_team'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13880\1915322370.py:1: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   shootouts2 = pd.concat(shootouts['home_team'],shootouts['away_team'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13880\1915322370.py in <module>
# ----> 1 shootouts2 = pd.concat(shootouts['home_team'],shootouts['away_team'])
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
# ...

# %%
goalscorers['date'] = pd.to_datetime(goalscorers['date'])
results['date'] = pd.to_datetime(results['date'])
shootouts['date'] = pd.to_datetime(shootouts['date'])

# %%
goalscorers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4263 entries, 39596 to 43858
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       4263 non-null   datetime64[ns]
#  1   home_team  4263 non-null   object
#  2   away_team  4263 non-null   object
#  3   team       4263 non-null   object
#  4   scorer     4263 non-null   object
#  5   minute     4263 non-null   float64
#  6   own_goal   4263 non-null   object
#  7   penalty    4263 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 299.7+ KB

# %%
goalscorers = goalscorers[(goalscorers['date']>'2000-01-01') & (goalscorers['date']<'2024-01-01')]

# %%
goalscorers
# Out:
#             date home_team    away_team      team             scorer  minute  \
# 19188 2000-01-22     Ghana     Cameroon  Cameroon    Marc-Vivien Foé    19.0
# 19189 2000-01-22     Ghana     Cameroon     Ghana         Kwame Ayew    57.0
# 19190 2000-01-23     Egypt       Zambia     Egypt      Yasser Radwan    37.0
# 19191 2000-01-23     Egypt       Zambia     Egypt      Hossam Hassan    50.0
# 19192 2000-01-23   Nigeria      Tunisia   Nigeria     Jay-Jay Okocha    28.0
# ...          ...       ...          ...       ...                ...     ...
# 43854 2023-11-21    Greece       France    France    Youssouf Fofana    74.0
# 43855 2023-11-21    Kosovo      Belarus   Belarus  Dmitry Antilevsky    43.0
# 43856 2023-11-21   Romania  Switzerland   Romania       Denis Alibec    50.0
# 43857 2023-11-21     Wales       Turkey     Wales      Neco Williams     7.0
# 43858 2023-11-21     Wales       Turkey    Turkey       Yusuf Yazıcı    70.0
#
#       own_goal penalty
# ...

# %%
goalscorers.to_csv("goalscorers_filtered3.csv")

# %%
results = results[(results['date']>'2000-01-01') & (results['date']<'2024-01-01')]

# %%
results
# Out:
#              date            home_team         away_team  home_score  \
# 24020  2000-01-04                Egypt              Togo         2.0
# 24021  2000-01-07              Tunisia              Togo         7.0
# 24022  2000-01-08  Trinidad and Tobago            Canada         0.0
# 24023  2000-01-09         Burkina Faso             Gabon         1.0
# 24024  2000-01-09            Guatemala           Armenia         1.0
# ...           ...                  ...               ...         ...
# 46768  2023-11-30                Samoa      Cook Islands         3.0
# 46769  2023-11-30               Tahiti  Papua New Guinea         2.0
# 46770  2023-12-01              Vanuatu              Fiji         2.0
# 46771  2023-12-02      Solomon Islands     New Caledonia         2.0
# 46772  2023-12-16               Mexico          Colombia         2.0
#
#        away_score     tournament             city              country  \
# ...

# %%
results[results['tournament']!='Friendly']
# Out:
#              date                 home_team         away_team  home_score  \
# 24040  2000-01-22                     Ghana          Cameroon         1.0
# 24041  2000-01-23                  China PR       Philippines         8.0
# 24042  2000-01-23                     Egypt            Zambia         2.0
# 24044  2000-01-23                   Nigeria           Tunisia         4.0
# 24045  2000-01-23              South Africa             Gabon         3.0
# ...           ...                       ...               ...         ...
# 46767  2023-11-30  Northern Mariana Islands            Tuvalu         1.0
# 46768  2023-11-30                     Samoa      Cook Islands         3.0
# 46769  2023-11-30                    Tahiti  Papua New Guinea         2.0
# 46770  2023-12-01                   Vanuatu              Fiji         2.0
# 46771  2023-12-02           Solomon Islands     New Caledonia         2.0
#
#        away_score                   tournament             city  \
# ...

# %%
results
# Out:
#             date        home_team         away_team  home_score  away_score  \
# 43288 2020-01-07         Barbados            Canada         1.0         4.0
# 43289 2020-01-09          Moldova            Sweden         0.0         1.0
# 43290 2020-01-10         Barbados            Canada         1.0         4.0
# 43291 2020-01-12           Kosovo            Sweden         0.0         1.0
# 43292 2020-01-15           Canada           Iceland         0.0         1.0
# ...          ...              ...               ...         ...         ...
# 46768 2023-11-30            Samoa      Cook Islands         3.0         0.0
# 46769 2023-11-30           Tahiti  Papua New Guinea         2.0         0.0
# 46770 2023-12-01          Vanuatu              Fiji         2.0         4.0
# 46771 2023-12-02  Solomon Islands     New Caledonia         2.0         2.0
# 46772 2023-12-16           Mexico          Colombia         2.0         3.0
#
# ...
